# %%
import csv

# %%
with open('viteos_investor_2.csv') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['from_date', 'to_date', 'quarter', 'investor_id', 'commitment_amount', 'less_contributions', 'ending_unfunded_comitment', 'ytd_distribution_to_lp_capital', 'distribution_to_lp', 'net_net_end_cap', 'si_carried_interest', 'ytd_management_fees', 'ytd_management_fees_offset']
# ['1/1/18', '3/31/18', 'Q1', '14b', ' \t1,000,000.00 ', ' \t31,000.00 ', ' \t905,000.00 ', ' \t-3,193.00', ' \t-11,443.00', ' \t91,314.68 ', ' \t-1,369.00', ' \t-1,475.96', ' \t-   ']
# ['4/1/18', '6/30/18', 'Q2', '14b', ' \t1,000,000.00 ', ' \t10,000.00 ', ' \t915,000.00 ', ' \t-7,265.00', ' \t-15,515.00', ' \t78,780.36 ', ' \t-1,692.59', ' \t-3,723.33', ' \t-   ']
# ['7/1/18', '9/30/18', 'Q3', '14b', ' \t1,000,000.00 ', ' \t-53,000.00', ' \t862,000.00 ', ' \t-11,850.00', ' \t-20,100.00', ' \t131,626.42 ', ' \t-2,422.31', ' \t-4,553.25', ' \t240.90 ']
# ...
